# %% [markdown]
# <a href="https://colab.research.google.com/github/pcriwtshah/Data-Science-Pre-requisites/blob/main/Line_plot_Spotfy_Streaming_Seaborn_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive/Colab Notebooks"
# Out:
# 'Copy of Heart Disease Diagnosis - Teacher Workshop (1).ipynb'
# 'Copy of Heart Disease Diagnosis - Teacher Workshop.ipynb'
# 'Copy of Trajectory of a projectile motion.ipynb'
#  fifa.csv
#  fifa.gsheet
#  fifa_ranking_seaborn_visualization.ipynb
# 'Graph of sinx and cosx.ipynb'
# 'Import Stock Prices.ipynb'
# 'Markdown and Latex Tutorial.ipynb'
# 'Matrix Operations.ipynb'
#  Numpy.ipynb
# 'Saalry line plot and bar diangram.ipynb'
# 'Some important inbuilt functions.ipynb'
#  spotify.csv
# 'Trajectory of a projectile motion.ipynb'
#  Untitled0.ipynb

# %%
# Path of the file to read
spotify_filepath = "/content/drive/My Drive/Colab Notebooks/spotify.csv"


# Read the file into a variable spotify_data
spotify_data = pd.read_csv(spotify_filepath, index_col="Date", parse_dates=True)

# %%
spotify_data.head(20)
# Out:
#             Shape of You  Despacito  ...  HUMBLE.  Unforgettable
# Date                                 ...
# 2017-01-06      12287078        NaN  ...      NaN            NaN
# 2017-01-07      13190270        NaN  ...      NaN            NaN
# 2017-01-08      13099919        NaN  ...      NaN            NaN
# 2017-01-09      14506351        NaN  ...      NaN            NaN
# 2017-01-10      14275628        NaN  ...      NaN            NaN
# 2017-01-11      14372699        NaN  ...      NaN            NaN
# 2017-01-12      14148108        NaN  ...      NaN            NaN
# 2017-01-13      14536236   275178.0  ...      NaN            NaN
# 2017-01-14      14173311  1144886.0  ...      NaN            NaN
# 2017-01-15      12889849  1288198.0  ...      NaN            NaN
# 2017-01-16      14128468  1827581.0  ...      NaN            NaN
# 2017-01-17      14158281  2177449.0  ...      NaN            NaN
# 2017-01-18      14293365  2528408.0  ...      NaN            NaN
# ...

# %%
spotify_data.tail()
# Out:
#             Shape of You  Despacito  ...    HUMBLE.  Unforgettable
# Date                                 ...
# 2018-01-05       4492978  3450315.0  ...  2685857.0      2869783.0
# 2018-01-06       4416476  3394284.0  ...  2559044.0      2743748.0
# 2018-01-07       4009104  3020789.0  ...  2350985.0      2441045.0
# 2018-01-08       4135505  2755266.0  ...  2523265.0      2622693.0
# 2018-01-09       4168506  2791601.0  ...  2727678.0      2627334.0
#
# [5 rows x 5 columns]

# %%
# Without setting the width and height of the figure
plt.figure()

# Line chart showing how FIFA rankings evolved over time 
sns.lineplot(data=spotify_data)

# %%
# Set the width and height of the figure
plt.figure(figsize=(16,6))

# Line chart showing how FIFA rankings evolved over time 
sns.lineplot(data=spotify_data)

# %%
# Set the width and height of the figure
plt.figure(figsize=(14,6))

# Add title
#Note that the title must always be enclosed in quotation marks ("...")!
plt.title("Daily Global Streams of Popular Songs in 2017-2018")

#Grid on
#xlabel is automatically true
plt.grid(True, which = 'both', axis= 'both')

#axis label
plt.ylabel('Streaming Count')

# Line chart showing daily global streams of each song 
sns.lineplot(data=spotify_data)

# %% [markdown]
# #Plot a subset of data

# %%
#print the names of all columns
spotify_data.columns
# Out:
# Index(['Shape of You', 'Despacito', 'Something Just Like This', 'HUMBLE.',
#        'Unforgettable'],
#       dtype='object')

# %%
#print the names of all columns
list(spotify_data.columns)
# Out:
# ['Shape of You',
#  'Despacito',
#  'Something Just Like This',
#  'HUMBLE.',
#  'Unforgettable']

# %%
#plot the lines corresponding to the first two columns in the dataset.
# Set the width and height of the figure
plt.figure(figsize=(14,6))

# Add title
plt.title("Daily Global Streams of Popular Songs in 2017-2018")

# Line chart showing daily global streams of 'Shape of You'
sns.lineplot(data=spotify_data['Shape of You'], label="Shape of You")

# Line chart showing daily global streams of 'Despacito'
sns.lineplot(data=spotify_data['Despacito'], label="Despacito")

# Add label for horizontal axis
plt.xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %%
# Change the style of the figure to the "dark" theme
sns.set_style("dark")

# Line chart 
plt.figure(figsize=(12,6))
sns.lineplot(data=spotify_data)

# %% [markdown]
# Seaborn has five different themes: (1)"darkgrid", (2)"whitegrid", (3)"dark", (4)"white", and (5)"ticks", and you need only use a command similar to the one in the code cell above (with the chosen theme filled in) to change it.
